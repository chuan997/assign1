# %% [markdown]
# ## **The interactive graph above shows the distribution of different complaint types in three different time patterns.**
#
# ### **About hourly pattern:** *An interesting phenomenon is that almost all the complaint types are created in the morning time like from 8:00 to 19:00, however, the social noise complaints show the opposite trend that they always happen between 19:00 to 2:00 in the second day.*
#
# ### **About weekly pattern:** *Some of the complaint types such as "Building/Use", "Derelict", "Dirty Conditions", "Plumbing" and "Paint" show that they are always happened on weekdays instead of weekends. By contrast, the frequencies of those social noise complaints are much higher on weekends.*
#
# ### **About monthly pattern:** *The "Heat/hot water" shows a special trend that in winter from November to March, the frequency of this complaint type is extremly high, however, in summer only few of this complaint. Besides, the different trend can be seen for the noises related to vehicle and street, which show higher frequencies in summer.*

# %% [markdown]
# # Now, let's explore the influence of pandemic on people's lives

# %% [markdown]
# Heatmap moives are plotted daily, weekly and monthly for four typical complaint types: **'Rodent', 'Noise - Commercial','Noise - Residential' and 'Blocked Driveway.** We choose two period befor(April to September in 2019) and after(November 2019 to April 2020) outbreak of COVID-19.

# %% [markdown]
# ## Let's start with the spatiotemporal patterns within a day before the pandemic.

# %% [markdown]
# Heatmap movie within a day before the pandemic

# %%
from IPython.display import HTML
from IPython.display import display
from IPython.display import HTML
import IPython.core.display as di
from IPython.display import IFrame

IFrame(src='hours_beforeCovid0.html', width=950, height=600)
# Out:
#         <iframe
#             width="950"
#             height="600"
#             src="hours_beforeCovid0.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# + The number of **'Rodent'** is relatively lower from **2 to 5am**. It happens frequenly during the day from 11 to 15. And what about spatial patterns?

# %% [markdown]
# + Complaints **residence and commercial noise** happen frequenly after 22 pm in the evening, but less during the day. The residence complaint incidents occur in the whole area, whereas the commercial complaints mainly happen in **Manhattan and Brooklyn.** The reason maybe be that there are more commercial areas in these districs.

# %% [markdown]
# + The traffic problems occurs during rush our like from 18 to 20，in almost area except Manhattan. This may be due to high housing costs.

# %% [markdown]
# ## You could find some interesting changes in spatiotemporal pattern during the pandemic.

# %% [markdown]
# Heatmap movie within a day after the pandemic

# %%
IFrame(src='hours_afterCovid0.html', width=950, height=600)
# Out:
#         <iframe
#             width="950"
#             height="600"
#             src="hours_afterCovid0.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# + The case **'Rodent'** amount decreses obviously from 11 to 15, especially in Brookly and Queens.

# %% [markdown]
# + There is an decrease in the case amount of **'Noise - Commercial'** especiall in Brookly, whereas the amount of case **'residence nosie'** increase slightly in the whloe area.

# %% [markdown]
# ## Then the monthly spatiotemporal patterns before pandemic will be shown

# %% [markdown]
# Monthly heatmap movie before the pandemic

# %%
IFrame(src='month_beforeCovid0.html', width=950, height=600)
# Out:
#         <iframe
#             width="950"
#             height="600"
#             src="month_beforeCovid0.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# + All the compaint types seem to remain constant during the period from April to September in 2019.

# %% [markdown]
# ## Then discover the monthly spatiotemporal patterns after pandemic

# %% [markdown]
# Monthly heatmap movie after the pandemic

# %%
IFrame(src='months_afterCovid0.html', width=950, height=600)
# Out:
#         <iframe
#             width="950"
#             height="600"
#             src="months_afterCovid0.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# + The period after January 2020 sees a significant decrease in the number of case **'Rodent'** in most areas except Manhattan.

# %% [markdown]
# + The amount of residence nosie complaint increases slightly after May, whereas the commercial noise and Blocked Drivway decreas significantly after April in Brookly. This may be the result of Coronavirus Shutdown. More and more people stay at home.

# %% [markdown]
# ## Additionally, the weekly spatiotemporal patterns is shown to explore more details.

# %% [markdown]
# Weekly heatmap movie before the pandemic

# %%
IFrame(src='weeks_beforeCovid0.html', width=950, height=600)
# Out:
#         <iframe
#             width="950"
#             height="600"
#             src="weeks_beforeCovid0.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ##

# %% [markdown]
# Weekly heatmap movie after the pandemic

# %%
IFrame(src='weeks_afterCovid0.html', width=950, height=600)
# Out:
#         <iframe
#             width="950"
#             height="600"
#             src="weeks_afterCovid0.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# **Do you find any interesting patterns during weekdays and weekends for different types correlated to pandemic?**
